# %%
import pandas as pd
import numpy as np
import os
import re

# %%
behavioral_risk_file = 'BRFSS_2014_Overall.csv'
census_directory = 'aff_download'
output_directory = 'data_cleaned'
# census data files
geographic_mobility = 'ACS_14_1YR_B07001_with_ann.csv'
home_language = 'ACS_14_1YR_S1601_with_ann.csv'
mean_income = 'ACS_14_1YR_S1902_with_ann.csv'
median_income = 'ACS_14_1YR_S1903_with_ann.csv'

# select census file
selected_file = home_language

# import files
risk_data = pd.read_csv(behavioral_risk_file)
compare = pd.read_csv(os.path.join(census_directory,selected_file))
for column in compare.keys():
    compare[column] = pd.to_numeric(compare[column], errors='ignore')

# %%
compare.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label  \
# 0           Id     Id2         Geography
# 1  0400000US01      01           Alabama
# 2  0400000US02      02            Alaska
# 3  0400000US04      04           Arizona
# 4  0400000US05      05          Arkansas
#
#                                   HC01_EST_VC01  \
# 0  Total; Estimate; Population 5 years and over
# 1                                       4558217
# 2                                        683324
# 3                                       6298821
# 4                                       2775973
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 5 years and...
# 1                                               2782
# 2                                                986
# 3                                               1394
# 4                                               2624
#
#                                        HC02_EST_VC01  \
# 0  Percent of specified language speakers  - Spea...
# 1                                               98.0
# 2                                               94.9
# 3                                               90.7
# 4                                               96.7
#
#                                        HC02_MOE_VC01  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                0.1
# 2                                                0.5
# 3                                                0.2
# 4                                                0.2
#
#                                        HC03_EST_VC01  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                2.0
# 2                                                5.1
# 3                                                9.3
# 4                                                3.3
#
#                                        HC03_MOE_VC01  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                0.1
# 2                                                0.5
# 3                                                0.2
# 4                                                0.2
#
#                          HC01_EST_VC02  \
# 0  Total; Estimate; Speak only English
# 1                                 95.1
# 2                                 83.4
# 3                                 73.0
# 4                                 93.1
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                        HC02_EST_VC36  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC02_MOE_VC36  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC03_EST_VC36  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC03_MOE_VC36  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC01_EST_VC37  \
# 0  Total; Estimate; PERCENT IMPUTED - Ability to ...
# 1                                                6.4
# 2                                                4.7
# 3                                                8.4
# 4                                                3.9
#
#                                        HC01_MOE_VC37  \
# 0  Total; Margin of Error; PERCENT IMPUTED - Abil...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC02_EST_VC37  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC02_MOE_VC37  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC03_EST_VC37  \
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                        HC03_MOE_VC37
# 0  Percent of specified language speakers  - Spea...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 189 columns]

# %%
def replace_str(x):
    try:
        float(x)
        return float(x)
    except:
        return np.NaN
data_cols = compare.keys()[5:]
for col in data_cols:
    compare[col][1:] = compare[col][1:].map(replace_str)
compare_clean = compare.dropna(axis=1,how='any').drop(columns=['GEO.id','GEO.id2']).set_index('GEO.display-label')

# %%
risk_questions = risk_data['Question'].unique()
print('Number of questions in Risk file to compare: %s' % len(risk_questions))
# Out:
# Number of questions in Risk file to compare: 64

# %%
filtered_questions = []
for n,q in enumerate(risk_questions):
    if re.search('aged',q) or re.search('race',q):
        print(f'{n}: {q}')
    else:
        filtered_questions.append(q)

print('')
for n,q in enumerate(filtered_questions):
    print(f'{n}: {q}')
# Out:
# 0: What is your race/ethnicity?
# 17: Adults aged 50+ who have had a blood stool test within the past two years (variable calculated from one or more BRFSS questions)
# 18: Adults aged 50-75 who have had a blood stool test within the past year (variable calculated from one or more BRFSS questions)
# 19: Adults aged 50+ who have ever had a sigmoidoscopy or colonoscopy (variable calculated from one or more BRFSS questions)
# 20: Respondents aged 50-75 who have fully met the USPSTF recommendation (variable calculated from one or more BRFSS questions)
# 41: Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)
# 45: Adults aged 65+ who have had a flu shot within the past year (variable calculated from one or more BRFSS questions)
# 46: Adults aged 65+ who have ever had a pneumonia vaccination (variable calculated from one or more BRFSS questions)
# 50: Adults aged 65+ who have had all their natural teeth extracted (variable calculated from one or more BRFSS questions)
# 55: Men aged 40+ who have had a PSA test within the past two years (variable calculated from one or more BRFSS questions)
# 59: Women aged 50-74 who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)
# 60: Women aged 50+ who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)
# 61: Women aged 40+ who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)
# 62: Women aged 18+ who have had a pap test within the past three years (variable calculated from one or more BRFSS questions)
# 63: Women aged 21-65 who have had a pap test in the past three years (variable calculated from one or more BRFSS questions)
#
# 0: Gender of respondent
# 1: Adults who have had at least one drink of alcohol within the past 30 days
# 2: Binge drinkers (males having five or more drinks on one occasion, females having four or more drinks on one occasion) (variable calculated from one or more BRFSS questions)
# 3: Heavy drinkers (adult men having more than two drinks per day and adult women having more than one drink per day) (variable calculated from one or more BRFSS questions)
# 4: Adults who have been told they have arthritis (variable calculated from one or more BRFSS questions)
# 5: Adults who have been told they currently have asthma (variable calculated from one or more BRFSS questions)
# 6: Adults who have ever been told they have asthma (variable calculated from one or more BRFSS questions)
# 7: Ever told you had angina or coronary heart disease?
# 8: Ever told you had a heart attack (myocardial infarction)?
# 9: Ever told you had a stroke?
# 10: Ever told you have COPD?
# 11: Ever told you that you have a form of depression?
# 12: Have you ever been told by a doctor that you have diabetes?
# 13: Ever told you have kidney disease?
# 14: Ever told you had any other types of cancer?
# 15: Ever told you had skin cancer?
# 16: What is your age?
# 17: Are you blind or do you have serious difficulty seeing, even when wearing glasses?
# 18: Do you have serious difficulty concentrating, remembering, or making decisions?
# 19: Do you have difficulty doing errands alone?
# 20: Do you have difficulty dressing or bathing?
# 21: Do you have serious difficulty walking or climbing stairs?
# 22: Adults who are limited in any activities because of physical, mental, or emotional problems
# 23: Adults with health problem(s) that requires the use of special equipment
# 24: What is the highest grade or year of school you completed?
# 25: What is your employment status?
# 26: What is your annual household income?
# 27: Have you used the internet in the past 30 days?
# 28: What is your marital status?
# 29: How many children live in your household? (variable calculated from one or more BRFSS questions)
# 30: Do you own or rent your home?
# 31: Have you ever served on active duty in the United States Armed Forces?
# 32: Was there a time in the past 12 months when you needed to see a doctor but could not because of cost?
# 33: Do you have any kind of health care coverage?
# 34: About how long has it been since you last visited a doctor for a routine checkup?
# 35: Do you have one person you think of as your personal doctor or health care provider?
# 36: Health Status (variable calculated from one or more BRFSS questions)
# 37: How is your general health?
# 38: Have you ever been tested for HIV?
# 39: Have you ever had the shingles or zoster vaccine?
# 40: Respondents who have reported having driven after drinking too much (variable calculated from one or more BRFSS questions)
# 41: Always wears a seat belt? (variable calculated from one or more BRFSS questions)
# 42: Visited the dentist or dental clinic within the past year for any reason (variable calculated from one or more BRFSS questions)
# 43: Adults that have had any permanent teeth extracted (variable calculated from one or more BRFSS questions)
# 44: Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)
# 45: During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)
# 46: Adults who are current smokers (variable calculated from one or more BRFSS questions)
# 47: Do you currently use chewing tobacco, snuff, or snus?
# 48: Four Level Smoking Status (variable calculated from one or more BRFSS questions)

# %%
for column in compare_clean.keys():
    compare_clean[column] = pd.to_numeric(compare_clean[column] , errors = 'coerce')
compare_clean.describe()
# Out:
#        HC01_EST_VC01  HC01_MOE_VC01  HC02_EST_VC01  HC02_MOE_VC01  \
# count   5.200000e+01      52.000000      52.000000      52.000000
# mean    5.816311e+06    1892.884615      93.023077       0.223077
# std     6.610916e+06     972.895288      10.864236       0.135206
# min     5.462240e+05       6.000000      21.600000       0.100000
# 25%     1.691520e+06    1217.750000      91.825000       0.100000
# 50%     3.941298e+06    1874.500000      95.550000       0.200000
# 75%     6.438912e+06    2551.750000      97.225000       0.225000
# max     3.629081e+07    4957.000000      99.400000       0.600000
#
#        HC03_EST_VC01  HC03_MOE_VC01  HC01_EST_VC02  HC01_MOE_VC02  \
# count      52.000000      52.000000      52.000000      52.000000
# mean        6.976923       0.223077      83.892308       0.344231
# std        10.864236       0.135206      14.800051       0.197448
# min         0.600000       0.100000       5.500000       0.100000
# 25%         2.775000       0.100000      78.800000       0.200000
# 50%         4.450000       0.200000      88.850000       0.300000
# 75%         8.175000       0.225000      93.025000       0.400000
# max        78.400000       0.600000      98.000000       0.900000
#
#        HC01_EST_VC03  HC01_MOE_VC03      ...        HC03_MOE_VC31  \
# count      52.000000      52.000000      ...            52.000000
# mean       16.107692       0.344231      ...             3.128846
# std        14.800051       0.197448      ...             2.103250
# min         2.000000       0.100000      ...             0.300000
# 25%         6.975000       0.200000      ...             1.700000
# 50%        11.150000       0.300000      ...             2.550000
# 75%        21.200000       0.400000      ...             4.375000
# max        94.500000       0.900000      ...             7.900000
#
#        HC01_EST_VC32  HC01_MOE_VC32  HC02_EST_VC32  HC02_MOE_VC32  \
# count      52.000000      52.000000      52.000000      52.000000
# mean        4.940385       0.226923      70.903846       2.876923
# std         3.759133       0.147017       6.689616       1.979465
# min         0.100000       0.100000      53.600000       0.500000
# 25%         2.175000       0.100000      67.775000       1.475000
# 50%         4.100000       0.200000      69.950000       2.250000
# 75%         6.675000       0.300000      74.275000       3.725000
# max        18.700000       0.700000      88.000000      11.800000
#
#        HC03_EST_VC32  HC03_MOE_VC32  HC01_EST_VC35  HC01_EST_VC36  \
# count      52.000000      52.000000      52.000000      52.000000
# mean       29.096154       2.876923       6.007692       5.590385
# std         6.689616       1.979465       0.931969       1.432981
# min        12.000000       0.500000       3.800000       2.500000
# 25%        25.725000       1.475000       5.400000       4.800000
# 50%        30.050000       2.250000       5.900000       5.400000
# 75%        32.225000       3.725000       6.525000       6.200000
# max        46.400000      11.800000       8.900000      11.100000
#
#        HC01_EST_VC37
# count      52.000000
# mean        6.248077
# std         1.458107
# min         3.100000
# 25%         5.400000
# 50%         6.100000
# 75%         6.900000
# max        11.800000
#
# [8 rows x 155 columns]

# %%
# for counter,question in enumerate(risk_questions):
#     print(f'{counter}: {question}')

# %%
n_per_q = 8
results = pd.DataFrame({'question':[],'combination':[],'R':[]})
for counter,question in enumerate(filtered_questions):
    this_question = risk_data.loc[risk_data['Question']==question].pivot(
        index = 'Locationdesc',columns = 'Response',values = 'Data_value')
    question_responses = list(this_question.keys())
    combined = this_question.merge(compare_clean.filter(
        regex='HC01_EST_VC0'), right_index=True, left_index=True, how='inner')
    compare_slices = list(compare_clean.filter(regex='HC01_EST_VC0').keys())

    correlation_matrix = combined.corr()
    corr_series = {}
    for this_slice in compare_slices:
        for response in question_responses:
    #         print(f'{this_slice},{response}:{correlation_matrix[this_slice][response]}')
            corr_series[f'{this_slice},{response}'] = abs(correlation_matrix[this_slice][response])
    corr_series = pd.Series(corr_series)
    corr_series.sort_values(ascending=False)
#     print(f'{counter}: {question}')
#     print(corr_series.sort_values(ascending=False).head(1))
    results = results.append(pd.DataFrame({'question': [question for i in range(n_per_q)], 
                                 'combination':corr_series.sort_values(ascending=False).head(n_per_q).index,
                                 'R':corr_series.sort_values(ascending=False).head(n_per_q).values
                                },index = [i for i in range(n_per_q*(counter),n_per_q*(counter+1))]))
#     print(results)
results.sort_values('R',ascending=False).head()
# Out:
#             R                                        combination  \
# 208  0.822810                    HC01_EST_VC04,Less than $15,000
# 200  0.773962                            HC01_EST_VC04,Homemaker
# 96   0.761591  HC01_EST_VC06,No, pre-diabetes or borderline d...
# 296  0.747801                                 HC01_EST_VC04,Fair
# 209  0.710191                    HC01_EST_VC03,Less than $15,000
#
#                                               question
# 208              What is your annual household income?
# 200                    What is your employment status?
# 96   Have you ever been told by a doctor that you h...
# 296                        How is your general health?
# 209              What is your annual household income?

# %%
top = results.sort_values('R',ascending=False).head(n_per_q*10)
top
# Out:
#             R                                        combination  \
# 208  0.822810                    HC01_EST_VC04,Less than $15,000
# 200  0.773962                            HC01_EST_VC04,Homemaker
# 96   0.761591  HC01_EST_VC06,No, pre-diabetes or borderline d...
# 296  0.747801                                 HC01_EST_VC04,Fair
# 209  0.710191                    HC01_EST_VC03,Less than $15,000
# 210  0.710191                    HC01_EST_VC02,Less than $15,000
# 297  0.706037                            HC01_EST_VC04,Very good
# 376  0.690721                            HC01_EST_VC05,Every day
# 211  0.687135                    HC01_EST_VC03,$35,000 -  49,999
# 212  0.687135                    HC01_EST_VC02,$35,000 -  49,999
# 224  0.673958                            HC01_EST_VC03,Partnered
# 225  0.673958                            HC01_EST_VC02,Partnered
# 226  0.671432                            HC01_EST_VC04,Partnered
# 192  0.659276                       HC01_EST_VC04,Less than H.S.
# 201  0.653269                            HC01_EST_VC02,Homemaker
# 202  0.653269                            HC01_EST_VC03,Homemaker
# 204  0.638668                          HC01_EST_VC02,No work >yr
# 203  0.638668                          HC01_EST_VC03,No work >yr
# 205  0.638391                          HC01_EST_VC04,No work >yr
# 384  0.634223                         HC01_EST_VC03,Never smoked
# 385  0.634223                         HC01_EST_VC02,Never smoked
# 298  0.632574                            HC01_EST_VC02,Very good
# 299  0.632574                            HC01_EST_VC03,Very good
# 300  0.626915                                 HC01_EST_VC03,Fair
# 301  0.626915                                 HC01_EST_VC02,Fair
# 213  0.623270                     HC01_EST_VC05,$25,000 - 34,999
# 387  0.621231                       HC01_EST_VC03,Smoke everyday
# 386  0.621231                       HC01_EST_VC02,Smoke everyday
# 88   0.617423                                   HC01_EST_VC06,No
# 89   0.616781                                  HC01_EST_VC06,Yes
# ..        ...                                                ...
# 115  0.563208                                   HC01_EST_VC02,No
# 288  0.553727                HC01_EST_VC04,Good or Better Health
# 289  0.552836                  HC01_EST_VC04,Fair or Poor Health
# 215  0.551491                             HC01_EST_VC04,$50,000+
# 381  0.551467                           HC01_EST_VC03,Not at all
# 380  0.551467                           HC01_EST_VC02,Not at all
# 136  0.550596                                  HC01_EST_VC04,Yes
# 137  0.548462                                   HC01_EST_VC04,No
# 228  0.544490                            HC01_EST_VC02,Separated
# 229  0.544490                            HC01_EST_VC03,Separated
# 121  0.540930                                   HC01_EST_VC02,No
# 120  0.540930                                   HC01_EST_VC03,No
# 352  0.539053        HC01_EST_VC05,Normal Weight (BMI 18.5-24.9)
# 122  0.538631                                  HC01_EST_VC03,Yes
# 123  0.538631                                  HC01_EST_VC02,Yes
# 8    0.528389                                   HC01_EST_VC05,No
# 9    0.528321                                  HC01_EST_VC05,Yes
# 248  0.526839                                  HC01_EST_VC04,Yes
# 249  0.524839                                   HC01_EST_VC04,No
# 280  0.519458                        HC01_EST_VC06,More than one
# 251  0.517691                                  HC01_EST_VC02,Yes
# 250  0.517691                                  HC01_EST_VC03,Yes
# 116  0.517089                                  HC01_EST_VC04,Yes
# 252  0.515165                                   HC01_EST_VC03,No
# 253  0.515165                                   HC01_EST_VC02,No
# 336  0.513279                                  HC01_EST_VC05,Yes
# 117  0.512113                                   HC01_EST_VC04,No
# 337  0.512113                                   HC01_EST_VC05,No
# 382  0.499045                            HC01_EST_VC05,Some days
# 302  0.497147                            HC01_EST_VC05,Excellent
#
#                                               question
# 208              What is your annual household income?
# 200                    What is your employment status?
# 96   Have you ever been told by a doctor that you h...
# 296                        How is your general health?
# 209              What is your annual household income?
# 210              What is your annual household income?
# 297                        How is your general health?
# 376  Do you currently use chewing tobacco, snuff, o...
# 211              What is your annual household income?
# 212              What is your annual household income?
# 224                       What is your marital status?
# 225                       What is your marital status?
# 226                       What is your marital status?
# 192  What is the highest grade or year of school yo...
# 201                    What is your employment status?
# 202                    What is your employment status?
# 204                    What is your employment status?
# 203                    What is your employment status?
# 205                    What is your employment status?
# 384  Four Level Smoking Status (variable calculated...
# 385  Four Level Smoking Status (variable calculated...
# 298                        How is your general health?
# 299                        How is your general health?
# 300                        How is your general health?
# 301                        How is your general health?
# 213              What is your annual household income?
# 387  Four Level Smoking Status (variable calculated...
# 386  Four Level Smoking Status (variable calculated...
# 88   Ever told you that you have a form of depression?
# 89   Ever told you that you have a form of depression?
# ..                                                 ...
# 115       Ever told you had any other types of cancer?
# 288  Health Status (variable calculated from one or...
# 289  Health Status (variable calculated from one or...
# 215              What is your annual household income?
# 381  Do you currently use chewing tobacco, snuff, o...
# 380  Do you currently use chewing tobacco, snuff, o...
# 136  Are you blind or do you have serious difficult...
# 137  Are you blind or do you have serious difficult...
# 228                       What is your marital status?
# 229                       What is your marital status?
# 121                     Ever told you had skin cancer?
# 120                     Ever told you had skin cancer?
# 352  Weight classification by Body Mass Index (BMI)...
# 122                     Ever told you had skin cancer?
# 123                     Ever told you had skin cancer?
# 8    Adults who have had at least one drink of alco...
# 9    Adults who have had at least one drink of alco...
# 248  Have you ever served on active duty in the Uni...
# 249  Have you ever served on active duty in the Uni...
# 280  Do you have one person you think of as your pe...
# 251  Have you ever served on active duty in the Uni...
# 250  Have you ever served on active duty in the Uni...
# 116       Ever told you had any other types of cancer?
# 252  Have you ever served on active duty in the Uni...
# 253  Have you ever served on active duty in the Uni...
# 336  Visited the dentist or dental clinic within th...
# 117       Ever told you had any other types of cancer?
# 337  Visited the dentist or dental clinic within th...
# 382  Do you currently use chewing tobacco, snuff, o...
# 302                        How is your general health?
#
# [80 rows x 3 columns]

# %%
list(top['combination'].map(lambda x: x[:13]).unique())
# Out:
# ['HC01_EST_VC04',
#  'HC01_EST_VC06',
#  'HC01_EST_VC03',
#  'HC01_EST_VC02',
#  'HC01_EST_VC05']

# %%
compare[top['combination'].map(lambda x: x[:13]).mode()[0]][0]
# Out:
# 'Total; Estimate; Speak a language other than English - Spanish or Spanish Creole'

# %%
select_questions = list(top.groupby(['question']).count().sort_values(['R'],ascending=False).head(4).index)
for n,q in enumerate(select_questions):
    print(f'{n+1}: {q}')
# Out:
# 1: What is your annual household income?
# 2: How is your general health?
# 3: Do you currently use chewing tobacco, snuff, or snus?
# 4: What is your employment status?

# %%
# Output to csv
question_map = {}
compare.filter(regex='HC01_EST_VC0').loc[0].map(lambda x: x[17:]).to_csv(os.path.join(output_directory,'demographics_map.csv'))
names = compare.filter(regex='HC01_EST_VC0').loc[0].map(lambda x: x[17:]).to_dict()
for counter,question in enumerate(select_questions):
    question_map[f'Q{counter+1}']=question
    this_question = risk_data.loc[risk_data['Question']==question].pivot(
        index = 'Locationdesc',columns = 'Response',values = 'Data_value')
    answer_map = {}
    for index,response in enumerate(risk_data.loc[(risk_data['Question']==question,'Response')].unique()):
        answer_map[f'A{index+1}'] = response
    pd.Series(answer_map).to_csv(os.path.join(output_directory,f'Q{counter+1}_answer_map.csv'))
    this_question.rename({value:key for key,value in answer_map.items()},axis='columns',inplace=True)
    question_responses = list(this_question.keys())
    combined = this_question.merge(compare_clean.filter(
        regex='HC01_EST_VC0'), right_index=True, left_index=True, how='inner')
#     combined.rename(names, axis='columns', inplace=True)
    combined.to_csv(os.path.join(output_directory,f'Q{counter+1}.csv'))
pd.Series(question_map).to_csv(os.path.join(output_directory,'question_map.csv'))
